# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import netCDF4 as ncdf
import numpy as np
import pandas as pd
import scipy as sp
from cal_cofi_plotting import *

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %% [markdown]
# # Cal COFI Stations

# %%
fig = plot_cal_cofi_stations('CalCOFIStationOrder.csv')
plt.show()

# %% [markdown]
# # Chlorophyll Density

# %%
fig = plot_cal_cofi_chlor('MW2022169_2022169_chla.nc')
plt.show()

# %% [markdown]
# # Save as png
# To save the figure as a png, use the `path_to_plot` parameter:<br>
# <br>
# ```python
# # Cal COFI stations
# plot_cal_cofi_stations('CalCOFIStationOrder.csv', path_to_plot='Cal_COFI_Stations.png')
# # Chlorophyll density
# plot_cal_cofi_chlor('MW2022169_2022169_chla.nc', path_to_plot='Chlor_density_2022169.png')
# ```
# <br>
